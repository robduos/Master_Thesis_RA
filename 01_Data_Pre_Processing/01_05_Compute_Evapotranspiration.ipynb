# %% [markdown]
# **Script Description:** This script loads a pre-processed dataset, and computes the Potential Evapotranspiration and Reference Evapotranspiration.
#
# **File Name:** 01_05_Compute_Evapotranspiration.ipynb
#
# **Date:** 2025
#
# **Created by:** Rob Alamgir

# %% [markdown]
# #### Import relevant packages

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import pyet
from pyet import penman
from pyet import abtew

# Use help() to view the available arguments
#help(pyet.penman)
#help(pyet.abtew)

# %% [markdown]
# #### Step 1: Load datasets and pre-process data

# %%
data_path = "C:/Data_MSc_Thesis/Pre_Processed_Data_Final/Pre_Processed_Data_All_Locations_V4.csv"
complete_dataset = pd.read_csv(data_path, low_memory=False)

complete_dataset = complete_dataset.rename(columns={'date': 'Date'})
complete_dataset['Date'] = pd.to_datetime(complete_dataset['Date']) # Convert 'date' column to datetime format
#print(complete_dataset.info()) 

# Load NOBV Site data
NOBV_Site_Data = pd.read_csv("C:/Data_MSc_Thesis/NOBV_Site_Data/NOBV_EC_Tower_Data_Final.csv")

# Merge the two dataframes based on 'Source' and 'Site_ID'
merged_df = pd.merge(complete_dataset, 
                     NOBV_Site_Data[['Site_ID', 'EPSG_4326_WGS_84_Longitude_X', 'EPSG_4326_WGS_84_Latitude_Y','Elevation_m']],
                     left_on='Source', right_on='Site_ID', how='left')

# Check if the 'Source' and 'Site_ID' columns match in the merged dataframe
merged_df['Source_matches_Site_ID'] = merged_df['Source'] == merged_df['Site_ID']
#print(merged_df[merged_df['Source_matches_Site_ID'] == False])

# Remove unnecessary columns for analysis
filtered_df_V1  = merged_df.drop(columns=[ 'Source','Source_matches_Site_ID'])

# Preprocess the input data
filtered_df_V2  = pd.DataFrame({"Date":filtered_df_V1.Date,
                                "Site_ID":filtered_df_V1.Site_ID,
                                "T":filtered_df_V1.ATMP_f,                  # temperature in [C°]
                                "RH":filtered_df_V1.RHUM_f,                 # relative_humidity [%°]
                                "R":filtered_df_V1.SWIN_f*0.0864,           # convert solar radiation from [(W/m^2)day^1] to [MJ m-2 d-1]
                                "u2":filtered_df_V1.WINS_f,                 # windspeed [m/s]
                                "PAIR":filtered_df_V1.PAIR_f*0.1,           # convert air pressure in [hPa] to [kPa]
                                "latitude":filtered_df_V1.EPSG_4326_WGS_84_Latitude_Y,
                                "Elevation":filtered_df_V1.Elevation_m})    # Elevation in [m] # Latitude of the meteorological station

# Remove rows with NaN values
filtered_df_V3 = filtered_df_V2.dropna()
#print(filtered_df_V3.info())

# %% [markdown]
# #### Step 2: Calculate Potential Evapotranspiration (PET) using Makkink method

# %%
# Calculate Potential Evapotranspiration (PET) using Makkink method for all rows at once (vectorized)
filtered_df_V3.loc[:, 'PET'] = pyet.makkink(
    tmean=filtered_df_V3['T'], 
    rs=filtered_df_V3['R'], 
    pressure=filtered_df_V3['PAIR'],
    elevation=filtered_df_V3['Elevation'],
    clip_zero=False)  # Avoid clipping of negative values

#print(filtered_df_V3.head())
#print(filtered_df_V3.info()) 
#print(filtered_df_V3.describe())

# %% [markdown]
# #### Step 3: Calculate reference evapotranspiration (ETo) using abtew method

# %%
# Calculate ET0 using Abtew method for all rows at once (vectorized) and add it directly to the original DataFrame
filtered_df_V3.loc[:, 'ET0'] = abtew(
    tmean=filtered_df_V3['T'],  # Average daily temperature in °C
    rs=filtered_df_V3['R'],     # Solar radiation in MJ m²/day
    clip_zero=True)             # Option to clip negative values (optional)

#print(filtered_df_V3.info()) 
#print(filtered_df_V3.describe())

# %%
print(complete_dataset.info())
print(filtered_df_V3.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8870 entries, 0 to 8869
# Data columns (total 74 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date                         8870 non-null   datetime64[ns]
#  1   year_month                   8870 non-null   object
#  2   year_week                    8870 non-null   object
#  3   DOY                          8870 non-null   float64
#  4   Source                       8870 non-null   object
#  5   SWCT_1_005                   8173 non-null   float64
#  6   SWCT_1_015                   8365 non-null   float64
#  7   SWCT_1_025                   8369 non-null   float64
#  8   SWCT_1_035                   8370 non-null   float64
#  9   SWCT_1_045                   8374 non-null   float64
#  10  SWCT_1_055                   8372 non-null   float64
#  11  SWCT_1_065                   8374 non-null   float64
#  12  SWCT_1_075                   8374 non-null   float64
#  13  SWCT_1_085                   8374 non-null   float64
#  14  SWCT_1_095                   8190 non-null   float64
#  15  SWCT_1_105                   8374 non-null   float64
#  16  SWCT_1_115                   8374 non-null   float64
#  17  STMP_1_005                   8258 non-null   float64
#  18  STMP_1_015                   8323 non-null   float64
#  19  STMP_1_025                   8320 non-null   float64
#  20  STMP_1_035                   8289 non-null   float64
#  21  STMP_1_045                   8291 non-null   float64
#  22  STMP_1_055                   8278 non-null   float64
#  23  STMP_1_065                   8302 non-null   float64
#  24  STMP_1_075                   8265 non-null   float64
#  25  STMP_1_085                   8214 non-null   float64
#  26  STMP_1_095                   8171 non-null   float64
#  27  STMP_1_105                   8252 non-null   float64
#  28  STMP_1_115                   7848 non-null   float64
#  29  WLEV_f                       7591 non-null   float64
#  30  WTMP_f                       2912 non-null   float64
#  31  ATMP_f                       8870 non-null   float64
#  32  PAIR_f                       8870 non-null   float64
#  33  WIND_f                       8870 non-null   float64
#  34  WINS_f                       8870 non-null   float64
#  35  RHUM_f                       8870 non-null   float64
#  36  RAIN_f                       8870 non-null   float64
#  37  RAIN_f_monthly_sum           8779 non-null   float64
#  38  RAIN_f_weekly_sum            8835 non-null   float64
#  39  VPD_f                        8734 non-null   float64
#  40  SWIN_f                       8870 non-null   float64
#  41  ET                           3346 non-null   float64
#  42  NEE_CO2                      3022 non-null   float64
#  43  NEE_CH4                      638 non-null    float64
#  44  GPP_NT                       7780 non-null   float64
#  45  RECO_NT                      8865 non-null   float64
#  46  NEE_CO2_kg_day_ha_DAv_24hrs  3022 non-null   float64
#  47  NEE_CH4_kg_day_ha_DAv_24hrs  638 non-null    float64
#  48  GPP_NT_kg_day_ha_DAv_24hrs   7780 non-null   float64
#  49  RECO_NT_kg_day_ha_DAv_24hrs  8865 non-null   float64
#  50  NEE_CO2_kg_day_ha_DAv_NT     2696 non-null   float64
#  51  NEE_CH4_kg_day_ha_DAv_NT     564 non-null    float64
#  52  GPP_NT_kg_day_ha_DAv_NT      3304 non-null   float64
#  53  RECO_NT_kg_day_ha_DAv_NT     3312 non-null   float64
#  54  NEE_CO2_kg_day_ha_DAv_DT     2848 non-null   float64
#  55  NEE_CH4_kg_day_ha_DAv_DT     605 non-null    float64
#  56  GPP_NT_kg_day_ha_DAv_DT      3299 non-null   float64
#  57  RECO_NT_kg_day_ha_DAv_DT     3308 non-null   float64
#  58  GPP_NT_kg_day_ha_DAv_NaN     7763 non-null   float64
#  59  RECO_NT_kg_day_ha_DAv_NaN    8858 non-null   float64
#  60  NEE_CO2_kg_day_ha_WAv_24hrs  628 non-null    float64
#  61  NEE_CH4_kg_day_ha_WAv_24hrs  160 non-null    float64
#  62  GPP_NT_kg_day_ha_WAv_24hrs   1122 non-null   float64
#  63  RECO_NT_kg_day_ha_WAv_24hrs  1265 non-null   float64
#  64  NEE_CO2_kg_day_ha_WAv_NT     602 non-null    float64
#  65  NEE_CH4_kg_day_ha_WAv_NT     150 non-null    float64
#  66  GPP_NT_kg_day_ha_WAv_NT      633 non-null    float64
#  67  RECO_NT_kg_day_ha_WAv_NT     634 non-null    float64
#  68  NEE_CO2_kg_day_ha_WAv_DT     625 non-null    float64
#  69  NEE_CH4_kg_day_ha_WAv_DT     156 non-null    float64
#  70  GPP_NT_kg_day_ha_WAv_DT      649 non-null    float64
#  71  RECO_NT_kg_day_ha_WAv_DT     650 non-null    float64
#  72  GPP_NT_kg_day_ha_WAv_NaN     1122 non-null   float64
#  73  RECO_NT_kg_day_ha_WAv_NaN    1265 non-null   float64
# dtypes: datetime64[ns](1), float64(70), object(3)
# memory usage: 5.0+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8870 entries, 0 to 8869
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       8870 non-null   datetime64[ns]
#  1   Site_ID    8870 non-null   object
#  2   T          8870 non-null   float64
#  3   RH         8870 non-null   float64
#  4   R          8870 non-null   float64
#  5   u2         8870 non-null   float64
#  6   PAIR       8870 non-null   float64
#  7   latitude   8870 non-null   float64
#  8   Elevation  8870 non-null   float64
#  9   PET        8870 non-null   float64
#  10  ET0        8870 non-null   float64
# dtypes: datetime64[ns](1), float64(9), object(1)
# memory usage: 762.4+ KB
# None

# %%
# Rename 'Source' to 'Site_ID' in complete_dataset
complete_dataset = complete_dataset.rename(columns={'Source': 'Site_ID'})

# Merge with filtered_df_V3 based on 'Date' and 'Site_ID'
complete_dataset = complete_dataset.merge(
    filtered_df_V3[['Date', 'Site_ID', 'PET', 'ET0']], 
    on=['Date', 'Site_ID'], 
    how='left')

# Reorder the columns by popping PET and ET0 and inserting them after ET
cols = list(complete_dataset.columns)
cols.remove('PET')
cols.remove('ET0')

# Find the index of 'ET' and insert 'PET' and 'ET0' after it
et_index = cols.index('ET') + 1
cols[et_index:et_index] = ['PET', 'ET0']

# Reassign the dataframe with the new column order
complete_dataset = complete_dataset[cols]

# %%
complete_dataset["P_minus_ET"] = complete_dataset["RAIN_f"] - complete_dataset["ET"]
complete_dataset["P_minus_PET"] = complete_dataset["RAIN_f"] - complete_dataset["PET"]

cols = list(complete_dataset.columns)  # Get the list of columns
idx_et0 = cols.index("ET0") + 1        # Position after ET0
cols = cols[:idx_et0] + ["P_minus_ET", "P_minus_PET"] + cols[idx_et0:]
complete_dataset = complete_dataset[cols]  # Reorder the dataframe

# %%
print(complete_dataset.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8870 entries, 0 to 8869
# Data columns (total 80 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date                         8870 non-null   datetime64[ns]
#  1   year_month                   8870 non-null   object
#  2   year_week                    8870 non-null   object
#  3   DOY                          8870 non-null   float64
#  4   Site_ID                      8870 non-null   object
#  5   SWCT_1_005                   8173 non-null   float64
#  6   SWCT_1_015                   8365 non-null   float64
#  7   SWCT_1_025                   8369 non-null   float64
#  8   SWCT_1_035                   8370 non-null   float64
#  9   SWCT_1_045                   8374 non-null   float64
#  10  SWCT_1_055                   8372 non-null   float64
#  11  SWCT_1_065                   8374 non-null   float64
#  12  SWCT_1_075                   8374 non-null   float64
#  13  SWCT_1_085                   8374 non-null   float64
#  14  SWCT_1_095                   8190 non-null   float64
#  15  SWCT_1_105                   8374 non-null   float64
#  16  SWCT_1_115                   8374 non-null   float64
#  17  STMP_1_005                   8258 non-null   float64
#  18  STMP_1_015                   8323 non-null   float64
#  19  STMP_1_025                   8320 non-null   float64
#  20  STMP_1_035                   8289 non-null   float64
#  21  STMP_1_045                   8291 non-null   float64
#  22  STMP_1_055                   8278 non-null   float64
#  23  STMP_1_065                   8302 non-null   float64
#  24  STMP_1_075                   8265 non-null   float64
#  25  STMP_1_085                   8214 non-null   float64
#  26  STMP_1_095                   8171 non-null   float64
#  27  STMP_1_105                   8252 non-null   float64
#  28  STMP_1_115                   7848 non-null   float64
#  29  WLEV_f                       7591 non-null   float64
#  30  WTMP_f                       2912 non-null   float64
#  31  ATMP_f                       8870 non-null   float64
#  32  PAIR_f                       8870 non-null   float64
#  33  WIND_f                       8870 non-null   float64
#  34  WINS_f                       8870 non-null   float64
#  35  RHUM_f                       8870 non-null   float64
#  36  RAIN_f                       8870 non-null   float64
#  37  RAIN_f_monthly_sum           8779 non-null   float64
#  38  RAIN_f_weekly_sum            8835 non-null   float64
#  39  VPD_f                        8734 non-null   float64
#  40  SWIN_f                       8870 non-null   float64
#  41  ET                           3346 non-null   float64
#  42  PET                          8870 non-null   float64
#  43  ET0                          8870 non-null   float64
#  44  P_minus_ET                   3346 non-null   float64
#  45  P_minus_PET                  8870 non-null   float64
#  46  NEE_CO2                      3022 non-null   float64
#  47  NEE_CH4                      638 non-null    float64
#  48  GPP_NT                       7780 non-null   float64
#  49  RECO_NT                      8865 non-null   float64
#  50  NEE_CO2_kg_day_ha_DAv_24hrs  3022 non-null   float64
#  51  NEE_CH4_kg_day_ha_DAv_24hrs  638 non-null    float64
#  52  GPP_NT_kg_day_ha_DAv_24hrs   7780 non-null   float64
#  53  RECO_NT_kg_day_ha_DAv_24hrs  8865 non-null   float64
#  54  NEE_CO2_kg_day_ha_DAv_NT     2696 non-null   float64
#  55  NEE_CH4_kg_day_ha_DAv_NT     564 non-null    float64
#  56  GPP_NT_kg_day_ha_DAv_NT      3304 non-null   float64
#  57  RECO_NT_kg_day_ha_DAv_NT     3312 non-null   float64
#  58  NEE_CO2_kg_day_ha_DAv_DT     2848 non-null   float64
#  59  NEE_CH4_kg_day_ha_DAv_DT     605 non-null    float64
#  60  GPP_NT_kg_day_ha_DAv_DT      3299 non-null   float64
#  61  RECO_NT_kg_day_ha_DAv_DT     3308 non-null   float64
#  62  GPP_NT_kg_day_ha_DAv_NaN     7763 non-null   float64
#  63  RECO_NT_kg_day_ha_DAv_NaN    8858 non-null   float64
#  64  NEE_CO2_kg_day_ha_WAv_24hrs  628 non-null    float64
#  65  NEE_CH4_kg_day_ha_WAv_24hrs  160 non-null    float64
#  66  GPP_NT_kg_day_ha_WAv_24hrs   1122 non-null   float64
#  67  RECO_NT_kg_day_ha_WAv_24hrs  1265 non-null   float64
#  68  NEE_CO2_kg_day_ha_WAv_NT     602 non-null    float64
#  69  NEE_CH4_kg_day_ha_WAv_NT     150 non-null    float64
#  70  GPP_NT_kg_day_ha_WAv_NT      633 non-null    float64
#  71  RECO_NT_kg_day_ha_WAv_NT     634 non-null    float64
#  72  NEE_CO2_kg_day_ha_WAv_DT     625 non-null    float64
#  73  NEE_CH4_kg_day_ha_WAv_DT     156 non-null    float64
#  74  GPP_NT_kg_day_ha_WAv_DT      649 non-null    float64
#  75  RECO_NT_kg_day_ha_WAv_DT     650 non-null    float64
#  76  GPP_NT_kg_day_ha_WAv_NaN     1122 non-null   float64
#  77  RECO_NT_kg_day_ha_WAv_NaN    1265 non-null   float64
#  78  P_minus_ET                   3346 non-null   float64
#  79  P_minus_PET                  8870 non-null   float64
# dtypes: datetime64[ns](1), float64(76), object(3)
# memory usage: 5.4+ MB
# None

# %% [markdown]
# ### Step 4: Export the final dataframe to a CSV file

# %%
output_path = "C:/Data_MSc_Thesis/Pre_Processed_Data_Final/Pre_Processed_Data_All_Locations_V5.csv"  # Update the path as needed
complete_dataset.to_csv(output_path, index=False)

print(f"DataFrame successfully saved to {output_path}")
# Out:
# DataFrame successfully saved to C:/Data_MSc_Thesis/Pre_Processed_Data_Final/Pre_Processed_Data_All_Locations_V5.csv
