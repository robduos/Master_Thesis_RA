# %% [markdown]
# #### Script Description
# This script loads the complete merged dataset, and splits the dataset to two seasonal periods.
#
# *File Name:* 01_10_Seasonal_Splitting.ipynb
#
# *Date:* 2025
#
# *Created by:* Rob Alamgir
#
# *Version:* 1.0
#
# *References:*

# %% [markdown]
# #### Import the relevant packages

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Step 1: Load Data

# %%
data_path = "C:/Data_MSc_Thesis/Pre_Processed_Data_Final/Pre_Processed_Data_All_Locations_V6.csv"
complete_dataset = pd.read_csv(data_path, low_memory=False)
complete_dataset['Date'] = pd.to_datetime(complete_dataset['Date']) # Convert 'date' column to datetime format
print(complete_dataset.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36275 entries, 0 to 36274
# Data columns (total 95 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date                         36275 non-null  datetime64[ns]
#  1   DOY                          8873 non-null   float64
#  2   Site_ID                      36275 non-null  object
#  3   year_month                   8873 non-null   object
#  4   S1_VSM                       17022 non-null  float64
#  5   S1_Backscatter               17022 non-null  float64
#  6   Planet_SWC                   35314 non-null  float64
#  7   Available_soil_storage_mm    12031 non-null  float64
#  8   S2_NDVI                      4260 non-null   float64
#  9   S2_EVI                       4260 non-null   float64
#  10  S2_NDMI                      4260 non-null   float64
#  11  L8_9_LST                     1565 non-null   float64
#  12  MODIS_LAI                    9032 non-null   float64
#  13  year_week                    8873 non-null   object
#  14  SWCT_1_005                   8242 non-null   float64
#  15  SWCT_1_015                   8532 non-null   float64
#  16  SWCT_1_025                   8533 non-null   float64
#  17  SWCT_1_035                   8530 non-null   float64
#  18  SWCT_1_045                   8534 non-null   float64
#  19  SWCT_1_055                   8532 non-null   float64
#  20  SWCT_1_065                   8534 non-null   float64
#  21  SWCT_1_075                   8534 non-null   float64
#  22  SWCT_1_085                   8534 non-null   float64
#  23  SWCT_1_095                   8258 non-null   float64
#  24  SWCT_1_105                   8534 non-null   float64
#  25  SWCT_1_115                   8534 non-null   float64
#  26  STMP_1_005                   8260 non-null   float64
#  27  STMP_1_015                   8325 non-null   float64
#  28  STMP_1_025                   8322 non-null   float64
#  29  STMP_1_035                   8291 non-null   float64
#  30  STMP_1_045                   8293 non-null   float64
#  31  STMP_1_055                   8280 non-null   float64
#  32  STMP_1_065                   8304 non-null   float64
#  33  STMP_1_075                   8267 non-null   float64
#  34  STMP_1_085                   8216 non-null   float64
#  35  STMP_1_095                   8173 non-null   float64
#  36  STMP_1_105                   8254 non-null   float64
#  37  STMP_1_115                   7850 non-null   float64
#  38  WLEV_f                       7593 non-null   float64
#  39  WTMP_f                       2913 non-null   float64
#  40  ATMP_f                       8873 non-null   float64
#  41  PAIR_f                       8873 non-null   float64
#  42  WIND_f                       8873 non-null   float64
#  43  WINS_f                       8873 non-null   float64
#  44  RHUM_f                       8873 non-null   float64
#  45  RAIN_f                       8873 non-null   float64
#  46  RAIN_f_monthly_sum           8782 non-null   float64
#  47  RAIN_f_weekly_sum            8838 non-null   float64
#  48  VPD_f                        8737 non-null   float64
#  49  SWIN_f                       8873 non-null   float64
#  50  ET                           3348 non-null   float64
#  51  PET                          8873 non-null   float64
#  52  ET0                          8873 non-null   float64
#  53  NEE_CO2                      3023 non-null   float64
#  54  NEE_CH4                      638 non-null    float64
#  55  GPP_NT                       7783 non-null   float64
#  56  RECO_NT                      8868 non-null   float64
#  57  NEE_CO2_kg_day_ha_DAv_24hrs  3023 non-null   float64
#  58  NEE_CH4_kg_day_ha_DAv_24hrs  638 non-null    float64
#  59  GPP_NT_kg_day_ha_DAv_24hrs   7783 non-null   float64
#  60  RECO_NT_kg_day_ha_DAv_24hrs  8868 non-null   float64
#  61  NEE_CO2_kg_day_ha_DAv_NT     2697 non-null   float64
#  62  NEE_CH4_kg_day_ha_DAv_NT     564 non-null    float64
#  63  GPP_NT_kg_day_ha_DAv_NT      3305 non-null   float64
#  64  RECO_NT_kg_day_ha_DAv_NT     3313 non-null   float64
#  65  NEE_CO2_kg_day_ha_DAv_DT     2849 non-null   float64
#  66  NEE_CH4_kg_day_ha_DAv_DT     605 non-null    float64
#  67  GPP_NT_kg_day_ha_DAv_DT      3301 non-null   float64
#  68  RECO_NT_kg_day_ha_DAv_DT     3310 non-null   float64
#  69  GPP_NT_kg_day_ha_DAv_NaN     7766 non-null   float64
#  70  RECO_NT_kg_day_ha_DAv_NaN    8861 non-null   float64
#  71  NEE_CO2_kg_day_ha_WAv_24hrs  628 non-null    float64
#  72  NEE_CH4_kg_day_ha_WAv_24hrs  160 non-null    float64
#  73  GPP_NT_kg_day_ha_WAv_24hrs   1122 non-null   float64
#  74  RECO_NT_kg_day_ha_WAv_24hrs  1265 non-null   float64
#  75  NEE_CO2_kg_day_ha_WAv_NT     602 non-null    float64
#  76  NEE_CH4_kg_day_ha_WAv_NT     150 non-null    float64
#  77  GPP_NT_kg_day_ha_WAv_NT      633 non-null    float64
#  78  RECO_NT_kg_day_ha_WAv_NT     634 non-null    float64
#  79  NEE_CO2_kg_day_ha_WAv_DT     625 non-null    float64
#  80  NEE_CH4_kg_day_ha_WAv_DT     156 non-null    float64
#  81  GPP_NT_kg_day_ha_WAv_DT      649 non-null    float64
#  82  RECO_NT_kg_day_ha_WAv_DT     650 non-null    float64
#  83  GPP_NT_kg_day_ha_WAv_NaN     1122 non-null   float64
#  84  RECO_NT_kg_day_ha_WAv_NaN    1265 non-null   float64
#  85  BD_0_5_values                34539 non-null  float64
#  86  BD_5_15_values               34539 non-null  float64
#  87  Clay_0_5_values              34539 non-null  float64
#  88  Clay_5_15_values             34539 non-null  float64
#  89  SOM_2020_0_5_values          34539 non-null  float64
#  90  SOM_2020_5_15_values         34539 non-null  float64
#  91  SOM_2023_0_5_values          34539 non-null  float64
#  92  SOM_2023_5_15_values         34539 non-null  float64
#  93  BOFEK_2020_Physical Units    34533 non-null  float64
#  94  Peat_Thickness_2022          36205 non-null  float64
# dtypes: datetime64[ns](1), float64(91), object(3)
# memory usage: 26.3+ MB
# None

# %%
# Ensure 'Date' column is in datetime format
complete_dataset['Date'] = pd.to_datetime(complete_dataset['Date'])

# Define seasons
complete_dataset['Season'] = complete_dataset['Date'].dt.month.map(
    lambda x: 'Wet' if x in [10, 11, 12, 1, 2, 3] else 'Dry')

# Compute hydrological balance (Rainfall - ET)
complete_dataset['Hydro_Balance'] = complete_dataset['RAIN_f'] - complete_dataset['ET']

# Classify into deficit (negative) or surplus (positive)
complete_dataset['Hydro_Status'] = complete_dataset['Hydro_Balance'].apply(
    lambda x: 'Deficit' if x < 0 else 'Surplus')

# %%
# Check updated dataframe
#complete_dataset.head(10)
print(complete_dataset.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36275 entries, 0 to 36274
# Data columns (total 98 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date                         36275 non-null  datetime64[ns]
#  1   DOY                          8873 non-null   float64
#  2   Site_ID                      36275 non-null  object
#  3   year_month                   8873 non-null   object
#  4   S1_VSM                       17022 non-null  float64
#  5   S1_Backscatter               17022 non-null  float64
#  6   Planet_SWC                   35314 non-null  float64
#  7   Available_soil_storage_mm    12031 non-null  float64
#  8   S2_NDVI                      4260 non-null   float64
#  9   S2_EVI                       4260 non-null   float64
#  10  S2_NDMI                      4260 non-null   float64
#  11  L8_9_LST                     1565 non-null   float64
#  12  MODIS_LAI                    9032 non-null   float64
#  13  year_week                    8873 non-null   object
#  14  SWCT_1_005                   8242 non-null   float64
#  15  SWCT_1_015                   8532 non-null   float64
#  16  SWCT_1_025                   8533 non-null   float64
#  17  SWCT_1_035                   8530 non-null   float64
#  18  SWCT_1_045                   8534 non-null   float64
#  19  SWCT_1_055                   8532 non-null   float64
#  20  SWCT_1_065                   8534 non-null   float64
#  21  SWCT_1_075                   8534 non-null   float64
#  22  SWCT_1_085                   8534 non-null   float64
#  23  SWCT_1_095                   8258 non-null   float64
#  24  SWCT_1_105                   8534 non-null   float64
#  25  SWCT_1_115                   8534 non-null   float64
#  26  STMP_1_005                   8260 non-null   float64
#  27  STMP_1_015                   8325 non-null   float64
#  28  STMP_1_025                   8322 non-null   float64
#  29  STMP_1_035                   8291 non-null   float64
#  30  STMP_1_045                   8293 non-null   float64
#  31  STMP_1_055                   8280 non-null   float64
#  32  STMP_1_065                   8304 non-null   float64
#  33  STMP_1_075                   8267 non-null   float64
#  34  STMP_1_085                   8216 non-null   float64
#  35  STMP_1_095                   8173 non-null   float64
#  36  STMP_1_105                   8254 non-null   float64
#  37  STMP_1_115                   7850 non-null   float64
#  38  WLEV_f                       7593 non-null   float64
#  39  WTMP_f                       2913 non-null   float64
#  40  ATMP_f                       8873 non-null   float64
#  41  PAIR_f                       8873 non-null   float64
#  42  WIND_f                       8873 non-null   float64
#  43  WINS_f                       8873 non-null   float64
#  44  RHUM_f                       8873 non-null   float64
#  45  RAIN_f                       8873 non-null   float64
#  46  RAIN_f_monthly_sum           8782 non-null   float64
#  47  RAIN_f_weekly_sum            8838 non-null   float64
#  48  VPD_f                        8737 non-null   float64
#  49  SWIN_f                       8873 non-null   float64
#  50  ET                           3348 non-null   float64
#  51  PET                          8873 non-null   float64
#  52  ET0                          8873 non-null   float64
#  53  NEE_CO2                      3023 non-null   float64
#  54  NEE_CH4                      638 non-null    float64
#  55  GPP_NT                       7783 non-null   float64
#  56  RECO_NT                      8868 non-null   float64
#  57  NEE_CO2_kg_day_ha_DAv_24hrs  3023 non-null   float64
#  58  NEE_CH4_kg_day_ha_DAv_24hrs  638 non-null    float64
#  59  GPP_NT_kg_day_ha_DAv_24hrs   7783 non-null   float64
#  60  RECO_NT_kg_day_ha_DAv_24hrs  8868 non-null   float64
#  61  NEE_CO2_kg_day_ha_DAv_NT     2697 non-null   float64
#  62  NEE_CH4_kg_day_ha_DAv_NT     564 non-null    float64
#  63  GPP_NT_kg_day_ha_DAv_NT      3305 non-null   float64
#  64  RECO_NT_kg_day_ha_DAv_NT     3313 non-null   float64
#  65  NEE_CO2_kg_day_ha_DAv_DT     2849 non-null   float64
#  66  NEE_CH4_kg_day_ha_DAv_DT     605 non-null    float64
#  67  GPP_NT_kg_day_ha_DAv_DT      3301 non-null   float64
#  68  RECO_NT_kg_day_ha_DAv_DT     3310 non-null   float64
#  69  GPP_NT_kg_day_ha_DAv_NaN     7766 non-null   float64
#  70  RECO_NT_kg_day_ha_DAv_NaN    8861 non-null   float64
#  71  NEE_CO2_kg_day_ha_WAv_24hrs  628 non-null    float64
#  72  NEE_CH4_kg_day_ha_WAv_24hrs  160 non-null    float64
#  73  GPP_NT_kg_day_ha_WAv_24hrs   1122 non-null   float64
#  74  RECO_NT_kg_day_ha_WAv_24hrs  1265 non-null   float64
#  75  NEE_CO2_kg_day_ha_WAv_NT     602 non-null    float64
#  76  NEE_CH4_kg_day_ha_WAv_NT     150 non-null    float64
#  77  GPP_NT_kg_day_ha_WAv_NT      633 non-null    float64
#  78  RECO_NT_kg_day_ha_WAv_NT     634 non-null    float64
#  79  NEE_CO2_kg_day_ha_WAv_DT     625 non-null    float64
#  80  NEE_CH4_kg_day_ha_WAv_DT     156 non-null    float64
#  81  GPP_NT_kg_day_ha_WAv_DT      649 non-null    float64
#  82  RECO_NT_kg_day_ha_WAv_DT     650 non-null    float64
#  83  GPP_NT_kg_day_ha_WAv_NaN     1122 non-null   float64
#  84  RECO_NT_kg_day_ha_WAv_NaN    1265 non-null   float64
#  85  BD_0_5_values                34539 non-null  float64
#  86  BD_5_15_values               34539 non-null  float64
#  87  Clay_0_5_values              34539 non-null  float64
#  88  Clay_5_15_values             34539 non-null  float64
#  89  SOM_2020_0_5_values          34539 non-null  float64
#  90  SOM_2020_5_15_values         34539 non-null  float64
#  91  SOM_2023_0_5_values          34539 non-null  float64
#  92  SOM_2023_5_15_values         34539 non-null  float64
#  93  BOFEK_2020_Physical Units    34533 non-null  float64
#  94  Peat_Thickness_2022          36205 non-null  float64
#  95  Season                       36275 non-null  object
#  96  Hydro_Balance                3348 non-null   float64
#  97  Hydro_Status                 36275 non-null  object
# dtypes: datetime64[ns](1), float64(92), object(5)
# memory usage: 27.1+ MB
# None

# %%
# Split the dataset based on the 'Season' column
Hydro_Wet_Season = complete_dataset[complete_dataset['Season'] == 'Wet'].copy()
Hydro_Dry_Season = complete_dataset[complete_dataset['Season'] == 'Dry'].copy()

# Display the number of rows in each dataframe
print(f"Hydro_Wet_Season: {Hydro_Wet_Season.shape[0]} rows")
print(f"Hydro_Dry_Season: {Hydro_Dry_Season.shape[0]} rows")
# Out:
# Hydro_Wet_Season: 17657 rows
# Hydro_Dry_Season: 18618 rows

# %% [markdown]
# #### Export the datasets

# %%
# Define file paths for export
Hydro_Wet_Season_data_path = "C:/Data_MSc_Thesis/Pre_Processed_Data_Final/Pre_Processed_Data_All_Locations_Updated_V6_Wet.csv"
Hydro_Dry_Season_data_path = "C:/Data_MSc_Thesis/Pre_Processed_Data_Final/Pre_Processed_Data_All_Locations_Updated_V6_Dry.csv"

# Export summer and winter data to CSV
Hydro_Wet_Season.to_csv(Hydro_Wet_Season_data_path, index=False)
Hydro_Dry_Season.to_csv(Hydro_Dry_Season_data_path, index=False)

print(f"Hydro_Wet_Season dataset exported to {Hydro_Wet_Season_data_path}.")
print(f"Hydro_Dry_Season dataset exported to {Hydro_Dry_Season_data_path}.")
# Out:
# Hydro_Wet_Season dataset exported to C:/Data_MSc_Thesis/Pre_Processed_Data_Final/Pre_Processed_Data_All_Locations_Updated_V6_Wet.csv.
# Hydro_Dry_Season dataset exported to C:/Data_MSc_Thesis/Pre_Processed_Data_Final/Pre_Processed_Data_All_Locations_Updated_V6_Dry.csv.
